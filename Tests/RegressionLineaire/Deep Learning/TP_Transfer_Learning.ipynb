# %% [markdown]
# Dans ce TP nous allons nous baser sur deux modèles pré-entrainés : VGG16 et ResNet50.
# Ces deux modèles sont les plus connus pour faire du Transfer Learning.
#
# Le but de ce TP va être de tester ces deux modèles sur plusieurs photos et comparer les prédictions associées.

# %% [markdown]
# 1. Allez récupérer sur internet trois photos :
#     - 1 photo de chat que vous enregistrerez sous cat.jpg
#     - 1 photo de chien que vous enregistrerez sous dog.jpg
#     - 1 photo d'une tasse que vous enregistrerez sous mug.jpg

# %% [markdown]
# # Transfer Learning

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions

# %% [markdown]
# ## Load the VGG16 Pre-trained Model

# %% [markdown]
# 2. Faites des recherches sur ce modèle VGG16. Depuis quand date ce modèle ? Quelle est son architecture ? Sur quelles données se basent ce modèle ? etc

# %%
# example of loading the vgg16 model
from keras.applications.vgg16 import VGG16
# load model
model = VGG16()
# summarize the model
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# 3. Recherchez ce que fait concrètement chacune des couches :
#  - flatten
#  - Dense
#  - Conv2D
#  - Maxpooling

# %% [markdown]
# # Load the ResNet50 Pre-trained Model

# %% [markdown]
# 4. Faites des recherches sur ce modèle ResNet50. Depuis quand date ce modèle ? Quelle est son architecture ? etc

# %%
# example of loading the resnet50 model
from keras.applications.resnet50 import ResNet50
# load model
model = ResNet50()
# summarize the model
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %% [markdown]
# 5. Idem, on connait la majorité des couches, exceptées :
#     ZeroPadding2D
#     BatchNomalization
# Que pouvez-vous en dire ?

# %% [markdown]
# # Prédiction

# %% [markdown]
# Vous allez tester le code ci-dessous avec chacune des photos (cat, dog et mug) et les deux modèles (VGG16 et ResNet50 et les prédictions associées).

# %%
# load an image from file
image = load_img('dog.jpg', target_size=(224, 224))
# convert the image pixels to a numpy array
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image
# Out:
# array([[[[200., 184., 158.],
#          [204., 185., 153.],
#          [200., 177., 161.],
#          ...,
#          [230., 216., 179.],
#          [238., 222., 186.],
#          [229., 209., 174.]],
#
#         [[201., 189., 165.],
#          [209., 194., 165.],
#          [207., 185., 171.],
#          ...,
#          [221., 212., 173.],
#          [223., 209., 172.],
#          [228., 210., 174.]],
#
#         [[233., 222., 200.],
#          [193., 179., 152.],
#          [174., 156., 144.],
#          ...,
#          [204., 196., 157.],
#          [223., 214., 175.],
#          [210., 196., 159.]],
#
#         ...,
#
#         [[172., 142., 140.],
#          [223., 190., 173.],
#          [224., 203., 172.],
#          ...,
#          [216., 200., 175.],
#          [190., 174., 148.],
#          [180., 165., 134.]],
#
#         [[149., 137., 115.],
#          [180., 142., 131.],
#          [202., 166., 154.],
#          ...,
#          [208., 192., 167.],
# ...

# %%
 image.shape[3]
# Out:
# 3

# %% [markdown]
# 6. Comment a été redimensionné l'image d'origine ?

# %%
# prepare the image for the VGG model
image = preprocess_input(image)
# predict the probability across all output classes
yhat = model.predict(image)
# convert the probabilities to class labels
label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]

# %%
label

# %% [markdown]
# 7. Faites un tableau récapitulatif des prédictions pour chacune des images selon le modèle, ainsi que la pourcentage de confiance associé.
