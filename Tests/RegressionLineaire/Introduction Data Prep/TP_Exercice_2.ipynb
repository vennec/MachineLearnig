# %% [markdown]
# # Etude du prix de l'immobilier à Boston
#
# Le but de cet exercice est de continuer la manipulation et l'analyse de dataset sur Python. Pour cela nous allons travailler sur un dataset contenant des données sur des ventes immobilières à Boston.

# %% [markdown]
# Installer le package sklearn

# %%
# Out:
# Requirement already satisfied: sklearn in c:\users\aliso\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\aliso\anaconda3\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aliso\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\aliso\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\aliso\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\aliso\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.0)

# %% [markdown]
#  1 - Importer les librairies dont vous aurez besoin

# %% [markdown]
#  2 -  Utilisez les lignes de codes suivantes afin de récupérer les données sur les prix de l’immobilier en Californie :
#
# from sklearn import datasets
# data = datasets.fetch_california_housing()
#
# NB : le descriptif des variables et données est disponible grâce à la commande print(data.DESCR)

# %% [markdown]
#  3 - Afficher votre dataset

# %%
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20640\n\n    :Number of Attributes: 8 numeric, predictive attributes and the target\n\n    :Attribute Information:\n        - MedInc        median income in block\n        - HouseAge      median house age in block\n        - AveRooms      average number of rooms\n        - AveBedrms     average number of bedrooms\n        - Population    block population\n        - AveOccup      average house occupancy\n        - Latitude      house block latitude\n        - Longitude     house block longitude\n\n    :Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttp://lib.stat.cmu.edu/datasets/\n\nThe target variable is the median house value for California districts.\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. topic:: References\n\n    - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n      Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %% [markdown]
#  4 - La manipulation ne peut se faire comme nous avions l'habiture de le faire.
#  Nous devons convertir notre dataset en dataframe. Pour cela il faut exécuter les requêtes suivantes :
#
# dataset = pd.DataFrame(columns=data["feature_names"], data=data.data)
# dataset = pd.concat([dataset,pd.DataFrame({"Price":data.target})], axis=1)
# dataset.head()

# %%
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
#  5 - Quel est la répartition de l'age des maisons ? Visualiser et commenter le résultat avec un graphique dont l'axe des abscisses est lisible

# %% [markdown]
#  6 - Visualiser à l'aide d'une courbe l'influence de l'age de la maison en fonction du prix

# %% [markdown]
#  7 - Regardez maintenant grâce à un scatter plot (fonction scatterplot()), la longitude et la latitude.  Au final, qu'est-ce que cela représente ?

# %% [markdown]
#  8 - A l'aide d'un boxplot, regarder la distribution de la colonne AveRooms. Que pouvez-vous en dire ?

# %% [markdown]
#  9 - Créer un nouveau dataset qui ne tient pas compte des valeurs atypiques (pour cela, on fixera les valeurs atypiques comme étant les valeurs > 20)

# %%
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
#  10 - Refaire les questions 8 et 9 et conclure.
