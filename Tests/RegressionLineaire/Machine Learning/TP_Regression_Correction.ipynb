# %% [markdown]
# # Regression

# %% [markdown]
# L'étude de la regression se fera via le dataset que vous connaissez bien : house_pricing.
# Nous allons donc prédire le prix de l'immobilier

# %% [markdown]
# 1. Import des bibliothèques

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn

# %% [markdown]
# 2. Import du jeu de données, directement via la bibliothèque sklearn

# %%
from sklearn import datasets
#data = datasets.california_housing.fetch_california_housing()
data = sklearn.datasets.fetch_california_housing(data_home=None, download_if_missing=True, return_X_y=False)#

# %%
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20640\n\n    :Number of Attributes: 8 numeric, predictive attributes and the target\n\n    :Attribute Information:\n        - MedInc        median income in block group\n        - HouseAge      median house age in block group\n        - AveRooms      average number of rooms per household\n        - AveBedrms     average number of bedrooms per household\n        - Population    block group population\n        - AveOccup      average number of household members\n        - Latitude      block group latitude\n        - Longitude     block group longitude\n\n    :Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,000).\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nAn household is a group of people residing within a home. Since the average\nnumber of rooms and bedrooms in this dataset are provided per household, these\ncolumns may take surpinsingly large values for block groups with few households\nand many empty houses, such as vacation resorts.\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. topic:: References\n\n    - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n      Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %% [markdown]
# Vérifions que nous avons bien une colonne "targer" : à savoir la colonne à prédire

# %%
print(data.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %% [markdown]
# De la même manière regardons les variables qui vont être des variables explicatives, c'est-à-dire qui vont nous aider à prédire la variable de sortie (=target)

# %%
data["feature_names"]
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# 4. Transformation du dataset en dataframe pour une meilleure manipulation

# %%
dataset = pd.DataFrame(columns=data["feature_names"], data=data.data)
dataset = pd.concat([dataset,pd.DataFrame({"Price":data.target})], axis=1)
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
# On redéfinit les variables target et feature_names

# %%
dataset = pd.DataFrame(data=data.data)
dataset.columns = data.feature_names
dataset["Price"] = data.target
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
corr_df = dataset.corr(method='pearson')

corr_df.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_c517f_row0_col0,#T_c517f_row1_col1,#T_c517f_row2_col2,#T_c517f_row3_col3,#T_c517f_row4_col4,#T_c517f_row5_col5,#T_c517f_row6_col6,#T_c517f_row7_col7,#T_c517f_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c517f_row0_col1{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_c517f_row0_col2{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_c517f_row0_col3{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_c517f_row0_col4{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_c517f_row0_col5{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_c517f_row0_col6{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_c517f_row0_col7{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_c517f_row0_col8{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_c517f_row1_col0,#T_c517f_row1_col2,#T_c517f_row1_col3,#T_c517f_row1_col4,#T_c517f_row4_col1,#T_c517f_row6_col7,#T_c517f_row6_col8,#T_c517f_row7_col6,#T_c517f_row8_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_c517f_row1_col5{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_c517f_row1_col6,#T_c517f_row3_col7{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_c517f_row1_col7,#T_c517f_row4_col6{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_c517f_row1_col8{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_c517f_row2_col0{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_c517f_row2_col1,#T_c517f_row4_col0{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_c517f_row2_col3{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_c517f_row2_col4{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_c517f_row2_col5,#T_c517f_row3_col5{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_c517f_row2_col6{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_c517f_row2_col7{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_c517f_row2_col8{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_c517f_row3_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_c517f_row3_col1{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_c517f_row3_col2{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_c517f_row3_col4{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_c517f_row3_col6{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_c517f_row3_col8,#T_c517f_row7_col3,#T_c517f_row7_col8{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_c517f_row4_col2{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_c517f_row4_col3{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_c517f_row4_col5,#T_c517f_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_c517f_row4_col7{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_c517f_row4_col8,#T_c517f_row5_col8{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_c517f_row5_col0{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_c517f_row5_col1{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_c517f_row5_col2{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_c517f_row5_col3{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_c517f_row5_col4{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_c517f_row5_col6,#T_c517f_row5_col7{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_c517f_row6_col0{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_c517f_row6_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_c517f_row6_col2{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_c517f_row6_col3{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_c517f_row6_col4,#T_c517f_row7_col1{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_c517f_row6_col5,#T_c517f_row7_col5{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_c517f_row7_col2{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_c517f_row7_col4{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_c517f_row8_col0{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_c517f_row8_col1{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_c517f_row8_col2{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_c517f_row8_col3{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_c517f_row8_col4{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_c517f_row8_col6{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_c517f_row8_col7{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }</style><table id="T_c517f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MedInc</th>        <th class="col_heading level0 col1" >HouseAge</th>        <th class="col_heading level0 col2" >AveRooms</th>        <th class="col_heading level0 col3" >AveBedrms</th>        <th class="col_heading level0 col4" >Population</th>        <th class="col_heading level0 col5" >AveOccup</th>        <th class="col_heading level0 col6" >Latitude</th>        <th class="col_heading level0 col7" >Longitude</th>        <th class="col_heading level0 col8" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c517f_level0_row0" class="row_heading level0 row0" >MedInc</th>
#                         <td id="T_c517f_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c517f_row0_col1" class="data row0 col1" >-0.119034</td>
#                         <td id="T_c517f_row0_col2" class="data row0 col2" >0.326895</td>
#                         <td id="T_c517f_row0_col3" class="data row0 col3" >-0.062040</td>
#                         <td id="T_c517f_row0_col4" class="data row0 col4" >0.004834</td>
#                         <td id="T_c517f_row0_col5" class="data row0 col5" >0.018766</td>
#                         <td id="T_c517f_row0_col6" class="data row0 col6" >-0.079809</td>
#                         <td id="T_c517f_row0_col7" class="data row0 col7" >-0.015176</td>
#                         <td id="T_c517f_row0_col8" class="data row0 col8" >0.688075</td>
#             </tr>
#             <tr>
#                         <th id="T_c517f_level0_row1" class="row_heading level0 row1" >HouseAge</th>
#                         <td id="T_c517f_row1_col0" class="data row1 col0" >-0.119034</td>
#                         <td id="T_c517f_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c517f_row1_col2" class="data row1 col2" >-0.153277</td>
#                         <td id="T_c517f_row1_col3" class="data row1 col3" >-0.077747</td>
#                         <td id="T_c517f_row1_col4" class="data row1 col4" >-0.296244</td>
#                         <td id=

# %% [markdown]
# 6. Créer un nuage de point du prix du salaire médian (MedInc) en fonction du Prix (Price)

# %%
sns.relplot(x="MedInc", y= "Price", data=dataset);

# %% [markdown]
# 7. regardez l'influence de l'age sur le prix de la maison

# %%
sns.relplot(x=dataset.columns[1], y=dataset.columns[-1], data= dataset, kind="line")

# %% [markdown]
# *Question* : que pouvez-vous en dire ?

# %% [markdown]
# 8. Découper votre dataset
# La variable y contient les valeurs de la colonne prix
# La variable x contient les autres colonne

# %%
X = dataset.iloc[:, :-1]
#X = dataset.drop(['Price', 'Latitude', 'AveOccup', 'HouseAge'], axis = 1)

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
y = dataset.iloc[:, -1:]

# %%
X.head()
# Out:
#    MedInc  AveRooms  AveBedrms  Population  Longitude
# 0  8.3252  6.984127   1.023810       322.0    -122.23
# 1  8.3014  6.238137   0.971880      2401.0    -122.22
# 2  7.2574  8.288136   1.073446       496.0    -122.24
# 3  5.6431  5.817352   1.073059       558.0    -122.25
# 4  3.8462  6.281853   1.081081       565.0    -122.25

# %%
y.head()
# Out:
#    Price
# 0  4.526
# 1  3.585
# 2  3.521
# 3  3.413
# 4  3.422

# %% [markdown]
# 9. Création du jeu d'entrainement et du jeu de test

# %% [markdown]
# Nous devons maintenant découper notre jeu d'entrainement. Pour cela, j'utilise la fonction train_test_split fournie par sklearn. Le paramètre test_size me permet de choisir la proportion de mon jeu de test. En règle général, cette valeur est comprise entre 0.2 et 0.3.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) #Remplacer les None par les bons paramètres

# %% [markdown]
# 10. effectuer votre régression linéaire
# Pour cela vous devrez utiliser la fonction LinearRegression() ainsi que fit() sur vos données X_train et Y_train

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 11. Utiliser la fonction score() sur votre Regressor pour afficher le score du modèle sur votre train puis sur votre test.
# Rappel : L'objectif est le suivant : avoir la plus petite erreur possible sur le jeu d'entrainement.

# %%
regressor.score(X_train, y_train)
# Out:
# 0.5097788439993948

# %%
regressor.score(X_test, y_test)
# Out:
# 0.5223243428217181

# %% [markdown]
# *Question* Comment interprêter ce score ? Est-ce que celui-ci vous semble acceptable ?
